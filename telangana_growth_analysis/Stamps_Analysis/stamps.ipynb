# %%
from pandas import *
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
import numpy as np

# %%
import matplotlib.ticker as ticker

# %%
df=read_csv("top_5_districts_rev_stamps.csv")

# %%
df['rev_in_mill']=df['total_rev_from_doc_gen'].apply(lambda x : np.round(x/1000000,2))

# %%
df
# Out:
#              district  total_rev_from_doc_gen  rev_in_mill
# 0  Medchal_Malkajgiri             48565874268     48565.87
# 1           Hyderabad             38396743983     38396.74
# 2          Rangareddy             30323651187     30323.65
# 3          Sangareddy             22024502771     22024.50
# 4         Hanumakonda              7927494100      7927.49

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
sns.set_palette('Purples')
# plt.ticklabel_format(style='plain', axis='x')
ax=sns.barplot(
    data=df,
    orient='h',
    x='rev_in_mill',
    y='district'
)
ax.bar_label(ax.containers[0])
plt.savefig("top_5_districts_rev_stamps.png")
# Out:
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df=read_csv("top_5_districts_estamp_gt_docs.csv")

# %%
def convert_to_million(x):
    return x/1000000

# %%
df['total_rev_from_docs_in_million']=df['total_rev_from_docs'].apply(convert_to_million)
df['total_rev_from_challans_in_million']=df['total_rev_from_challans'].apply(convert_to_million)

# %%
df
# Out:
#               district  total_rev_from_docs  total_rev_from_challans  \
# 0   Medchal_Malkajgiri          15029903525              15080153526
# 1            Hyderabad          14266012441              14374315032
# 2          Hanumakonda           2817238587               2846856844
# 3  Yadadri Bhuvanagiri           2167480603               2185270667
# 4              Khammam           1971647539               2002220314
#
#    total_rev_from_docs_in_million  total_rev_from_challans_in_million
# 0                    15029.903525                        15080.153526
# 1                    14266.012441                        14374.315032
# 2                     2817.238587                         2846.856844
# 3                     2167.480603                         2185.270667
# 4                     1971.647539                         2002.220314

# %%
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")

sns.barplot(
    data=df,
    x='district',
    y='total_rev_from_docs_in_million'
)
# Out:
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='district', ylabel='total_rev_from_docs_in_million'>

# %%
df[['total_rev_from_challans_in_million','total_rev_from_docs_in_million']].plot.bar()
# fig, ax = plt.subplots(figsize=(10, 6)) 
# plt.figure(figsize=(10,20))
plt.xlabel('Districts')
plt.ylabel('Revenue (in million)')
plt.title('Revenue from Challans and Documents by District')
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.savefig('top_5_districts_estamp_gt_docs.png', dpi=300) 
# plt.savefig("top_5_districts_estamp_gt_docs.jpg")

# %%
df.district.values
# Out:
# array(['Medchal_Malkajgiri', 'Hyderabad', 'Hanumakonda',
#        'Yadadri Bhuvanagiri', 'Khammam'], dtype=object)

# %%
df=read_csv("count_of_docs_before_estamp_by_month.csv",parse_dates=['month'])

# %%
df
# Out:
#         month  total_docs_registered
# 0  2019-04-01                 130223
# 1  2019-05-01                 144201
# 2  2019-06-01                 133916
# 3  2019-07-01                 158479
# 4  2019-08-01                 144914
# 5  2019-09-01                 131759
# 6  2019-10-01                 125855
# 7  2019-11-01                 122205
# 8  2019-12-01                 140440
# 9  2020-01-01                 120851
# 10 2020-02-01                 122852
# 11 2020-03-01                 112423
# 12 2020-04-01                   4492
# 13 2020-05-01                  73005
# 14 2020-06-01                 136196
# 15 2020-07-01                 126672
# 16 2020-08-01                 104469
# 17 2020-09-01                  23255
# 18 2020-10-01                    480
# 19 2020-11-01                    277

# %%
# plt.figure(figsize=(7,5))

plt.plot(df.month,df.total_docs_registered)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.xlabel("Month")
plt.ylabel("count of docs")
plt.title('count_of_docs_before_estamp_by_month')
plt.tight_layout()
plt.savefig("count_of_docs_before_estamp_by_month.png",dpi=300)

# %%
sns.lineplot(data=df,x='month',y='total_docs_registered')
# Out:
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\vivek chouhan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df=read_csv("count_of_docs_before_estamp_by_year.csv")
df['year(month)']=df['year(month)'].astype(str)
df.total_docs_registered=df.total_docs_registered.apply(convert_to_million)
# df.set_index('year(month)', inplace=True)

# %%
df
# Out:
#   year(month)  total_docs_registered
# 0        2019               1.231992
# 1        2020               0.824972

# %%
plt.plot(df['year(month)'],df.total_docs_registered)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.xlabel("Year")
plt.ylabel("count of docs")
plt.title('count_of_docs_before_estamp_by_year')
plt.tight_layout()
# plt.savefig("count_of_docs_before_estamp_by_month.png",dpi=300)

# %%
df=read_csv("count_of_docs_after_estamp_by_month.csv.",parse_dates=['month'])

# %%
df.set_index('month', inplace=True)

# %%
df.plot.line()
plt.title('count_of_docs and stamps_after_estamp_by_month')
plt.tight_layout()
# plt.savefig("count_of_docs_after_estamp_by_month.png",dpi=300)

# %%
from datetime import datetime
from random import randint

# %%
df.set_index('month', inplace=True)

# %%
df.head()
# Out:
#             total_docs_registered  total_stamps_registered
# month
# 2019-04-01                 130223                        0
# 2019-05-01                 144201                        0
# 2019-06-01                 133916                        0
# 2019-07-01                 158479                        0
# 2019-08-01                 144914                        0

# %%
# df.set_index('date', inplace=True)

# Create the figure and axis
fig, ax = plt.subplots(1, 1, figsize = (6, 6))

# Set x and y axis labels
ax.set_xlabel('Date')
ax.set_ylabel('Total Revenue')
ax.set_title('Total Revenue Over Time')

# Display legend
ax.legend()

# Function to update the plot at each frame


def animate(i):
    ax.cla() # clear the previous image
    ax.plot(df.index[:i], df.total_docs_registered[:i],color='red') # plot the line
    ax.plot(df.index[:i], df.total_stamps_registered[:i],color='blue')
    ax.set_xlim([df.index[0], df.index[-1]]) # fix the x axis
    ax.set_ylim([-1, np.max(df.total_docs_registered)+100]) # fix the y axis
    # ax.set_xticks(df.index[:i])

# Create an animation
animation = FuncAnimation(fig, animate, frames=len(df)+1, interval=500, blit=False)

# Save the animation as a GIF using Pillow
# animation.save('revenue_animation_pillow.gif', writer='pillow', fps=2)

# Close the figure
plt.close()

from IPython.display import HTML
HTML(animation.to_html5_video())
# 2. render and display the desired animation by rc
from matplotlib import rc
# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')
animation
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df
# Out:
#             total_docs_registered  total_stamps_registered
# month
# 2019-04-01                 130223                        0
# 2019-05-01                 144201                        0
# 2019-06-01                 133916                        0
# 2019-07-01                 158479                        0
# 2019-08-01                 144914                        0
# 2019-09-01                 131759                        0
# 2019-10-01                 125855                        0
# 2019-11-01                 122205                        0
# 2019-12-01                 140440                        0
# 2020-01-01                 120851                        0
# 2020-02-01                 122852                        0
# 2020-03-01                 112423                        0
# 2020-04-01                   4492                        0
# 2020-05-01                  73005                        0
# 2020-06-01                 136196                        0
# ...
